# %%
import gym  
import gym_examples  
import numpy as np                                  
import random               
# used to help with visualizing in Colab                 
from IPython.display import display, clear_output   
from time import sleep
num_steps = 50
penalties = 0
# Out:
# Traceback (most recent call last):
#
#   File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3251 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Input In [1] in <module>
#     import gym_examples
#
#   File c:\users\jimmy\desktop\央央\python 機器學習\gym-examples\gym_examples\__init__.py:11
#     max_episode_steps=200
#     ^
# SyntaxError: invalid syntax

# %%
class bcolors:
    RED= '\u001b[31m'
    GREEN= '\u001b[32m'
    RESET= '\u001b[0m'

# create Taxi environment
env = gym.make('gym_examples/taxi-v2')

# initialize q-table
state_size = env.observation_space.n
action_size = env.action_space.n
qtable = np.zeros((state_size, action_size))

# hyperparameters
learning_rate = 0.9
discount_rate = 0.8
epsilon = 1.0
decay_rate= 0.005

# training variables
num_episodes = 20000
max_steps = 200 # per episode

print("AGENT IS TRAINING...")

for episode in range(num_episodes):

	# Reset the environment
	state = env.reset()
	step = 0
	done = False
    
	for step in range(max_steps):

		# Exploration-exploitation tradeoff
		if random.uniform(0,1) < epsilon:
			# Explore
			action = env.action_space.sample()
		else:
			# Exploit
			action = np.argmax(qtable[state,:])

		# Take an action and observe the reward
		new_state, reward, done, info = env.step(action)

		# Q-learning algorithm
		qtable[state,action] = qtable[state,action] + learning_rate * (reward + discount_rate * np.max(qtable[new_state,:])-qtable[state,action])

		# Update to our new state
		state = new_state

		# if done, finish episode
		if done == True:
			break

	# Decrease epsilon
	epsilon = np.exp(-decay_rate*episode)
	
# Get ready to watch our trained agent
clear_output()
print(f"Our Q-table: {qtable}")
print(f"Training completed over {num_episodes} episodes")
input("Press Enter to see our trained taxi agent")
sleep(1)
clear_output()  

episodes_to_preview = 20
for episode in range(episodes_to_preview):

	# Reset the environment
	state = env.reset()
	step = 0
	done = False
	episode_rewards = 0

	for step in range(num_steps):
		# clear screen
		clear_output(wait=True)

		print(f"TRAINED AGENT")
		print(f"+++++EPISODE {episode+1}+++++")
		print(f"Step {step+1}")

		# Exploit
		action = np.argmax(qtable[state,:])

		# Take an action and observe the reward
		new_state, reward, done, info = env.step(action)

		# Accumulate our rewards    
		episode_rewards += reward

		env.render()
		print("")
		if episode_rewards < 0:
			print(f"Score: {bcolors.RED}{episode_rewards}{bcolors.RESET}")
		else:
			print(f"Score: {bcolors.GREEN}{episode_rewards}{bcolors.RESET}")
		sleep(0.1)   
		    
		# Update to our new state
		state = new_state

		# if done, finish episode
		if done == True:
			break
            

# Close the Taxi environment
env.close()
# Out:
# ---------------------------------------------------------------------------
# NamespaceNotFound                         Traceback (most recent call last)
# Input In [2], in <module>
#       4     RESET= '\u001b'
#       6 # create Taxi environment
# ----> 7 env = gym.make('gym_examples/taxi-v2')
#       9 # initialize q-table
#      10 state_size = env.observation_space.n
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\gym\envs\registration.py:676, in make(id, **kwargs)
#     675 def make(id: str, **kwargs) -> "Env":
# --> 676     return registry.make(id, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\gym\envs\registration.py:490, in EnvRegistry.make(self, path, **kwargs)
#     487 namespace, name, version = parse_env_id(path)
#     489 # Get all versions of this spec.
# --> 490 versions = self.env_specs.versions(namespace, name)
#     492 # We check what the latest version of the environment is and display
#     493 # a warning if the user is attempting to initialize an older version
#     494 # or an unversioned one.
#     495 latest_versioned_spec = max(
#     496     filter(lambda spec: spec.version, versions),
#     497     key=lambda spec: cast(int, spec.version),
#     498     default=None,
#     499 )
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\gym\envs\registration.py:220, in EnvSpecTree.versions(self, namespace, name)
#     203 def versions(self, namespace: Optional[str], name: str) -> Sequence[EnvSpec]:
#     204     """
#     205     Returns the versions associated with a namespace and name.
#     206
#    (...)
#     218     See `gym/envs/__relocated__.py` for more info.
#     219     """
# --> 220     self._assert_name_exists(namespace, name)
#     222     versions = list(self.tree[namespace][name].values())
#     224     if namespace is None and name in internal_env_relocation_map:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\gym\envs\registration.py:271, in EnvSpecTree._assert_name_exists(self, namespace, name)
#     270 def _assert_name_exists(self, namespace: Optional[str], name: str) -> None:
# --> 271     self._assert_namespace_exists(namespace)
#     272     if name in self.tree[namespace]:
#     273         return
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\gym\envs\registration.py:268, in EnvSpecTree._assert_namespace_exists(self, namespace)
#     266     else:
#     267         message += f" Have you installed the proper package for `{namespace}`?"
# --> 268 raise error.NamespaceNotFound(message)
#
# NamespaceNotFound: Namespace `gym_examples` does not exist. Have you installed the proper package for `gym_examples`?
